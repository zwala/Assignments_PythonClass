# %%
import pandas as pd

# %%
# %timeit sheet1=pd.read_excel('part-00010-of-00500_1.xlsx')

# %%
sheet1
# Out:
#         50712000000  51000000000  4665896876   333      421565   0.03864  \
# 0       50712000000  51000000000  4969889774    47   318473412  0.040340
# 1       50712000000  51000000000  6221861800  4348   351618628  0.014310
# 2       50712000000  51000000000  6221861800  4354   351618628  0.014310
# 3       50712000000  50713000000  6221861800  4391  2497958300  0.000000
# 4       50712000000  50978000000  6238340468  1350   351634289  0.022250
# 5       50712000000  51000000000  6252901355    95  2898880161  0.002510
# 6       50712000000  50736000000  6253322190   876   295014299  0.047120
# 7       50712000000  51000000000  6253482179  2142  3720912062  0.034300
# 8       50712000000  51000000000  6253482179  2869  3720912062  0.036990
# 9       50712000000  51000000000  6254584038   321      660272  0.019560
# 10      50712000000  50993000000  6254584038   331   351613851  0.017400
# 11      50712000000  50898000000  6254584038   492     6566576  0.008118
# ...
