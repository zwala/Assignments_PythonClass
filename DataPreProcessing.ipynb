# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_excel('Country_data.xlsx')

# %%
dataset
# Out:
#    Unnamed: 0  id  Country   Age   Salary Purchased
# 0         NaN   0   France  44.0  72000.0        No
# 1         NaN   1    Spain  27.0  48000.0       Yes
# 2         NaN   2  Germany  30.0  54000.0        No
# 3         NaN   3    Spain  38.0  61000.0        No
# 4         NaN   4  Germany  40.0      NaN       Yes
# 5         NaN   5   France  35.0  58000.0       Yes
# 6         NaN   6    Spain   NaN  52000.0        No
# 7         NaN   7   France  48.0  79000.0       Yes
# 8         NaN   8  Germany  50.0  83000.0        No
# 9         NaN   9   France  37.0  67000.0       Yes

# %%
dataset.shape
# Out:
# (10, 6)

# %%
copy_data=dataset

# %%
copy_data
# Out:
#    Unnamed: 0  id  Country   Age   Salary Purchased
# 0         NaN   0   France  44.0  72000.0        No
# 1         NaN   1    Spain  27.0  48000.0       Yes
# 2         NaN   2  Germany  30.0  54000.0        No
# 3         NaN   3    Spain  38.0  61000.0        No
# 4         NaN   4  Germany  40.0      NaN       Yes
# 5         NaN   5   France  35.0  58000.0       Yes
# 6         NaN   6    Spain   NaN  52000.0        No
# 7         NaN   7   France  48.0  79000.0       Yes
# 8         NaN   8  Germany  50.0  83000.0        No
# 9         NaN   9   France  37.0  67000.0       Yes

# %%
dataset=copy_data.rename(columns={'Unnamed: 0':'Random', 'id':'Id'})

# %%
copy_data
# Out:
#    Random  Id  Country   Age   Salary Purchased
# 0     NaN   0   France  44.0  72000.0        No
# 1     NaN   1    Spain  27.0  48000.0       Yes
# 2     NaN   2  Germany  30.0  54000.0        No
# 3     NaN   3    Spain  38.0  61000.0        No
# 4     NaN   4  Germany  40.0      NaN       Yes
# 5     NaN   5   France  35.0  58000.0       Yes
# 6     NaN   6    Spain   NaN  52000.0        No
# 7     NaN   7   France  48.0  79000.0       Yes
# 8     NaN   8  Germany  50.0  83000.0        No
# 9     NaN   9   France  37.0  67000.0       Yes

# %%
copy_data.isnull()
# Out:
#    Random     Id  Country    Age  Salary  Purchased
# 0    True  False    False  False   False      False
# 1    True  False    False  False   False      False
# 2    True  False    False  False   False      False
# 3    True  False    False  False   False      False
# 4    True  False    False  False    True      False
# 5    True  False    False  False   False      False
# 6    True  False    False   True   False      False
# 7    True  False    False  False   False      False
# 8    True  False    False  False   False      False
# 9    True  False    False  False   False      False

# %%
copy_data.isnull().sum()
# Out:
# Random       10
# Id            0
# Country       0
# Age           1
# Salary        1
# Purchased     0
# dtype: int64

# %%
dataset
# Out:
#    Random  Id  Country   Age   Salary Purchased
# 0     NaN   0   France  44.0  72000.0        No
# 1     NaN   1    Spain  27.0  48000.0       Yes
# 2     NaN   2  Germany  30.0  54000.0        No
# 3     NaN   3    Spain  38.0  61000.0        No
# 4     NaN   4  Germany  40.0      NaN       Yes
# 5     NaN   5   France  35.0  58000.0       Yes
# 6     NaN   6    Spain   NaN  52000.0        No
# 7     NaN   7   France  48.0  79000.0       Yes
# 8     NaN   8  Germany  50.0  83000.0        No
# 9     NaN   9   France  37.0  67000.0       Yes

# %%
copy_data.dropna(inplace=False)
# Out:
# Empty DataFrame
# Columns: [Random, Id, Country, Age, Salary, Purchased]
# Index: []

# %%
copy_data
# Out:
#    Random  Id  Country   Age   Salary Purchased
# 0     NaN   0   France  44.0  72000.0        No
# 1     NaN   1    Spain  27.0  48000.0       Yes
# 2     NaN   2  Germany  30.0  54000.0        No
# 3     NaN   3    Spain  38.0  61000.0        No
# 4     NaN   4  Germany  40.0      NaN       Yes
# 5     NaN   5   France  35.0  58000.0       Yes
# 6     NaN   6    Spain   NaN  52000.0        No
# 7     NaN   7   France  48.0  79000.0       Yes
# 8     NaN   8  Germany  50.0  83000.0        No
# 9     NaN   9   France  37.0  67000.0       Yes

# %%
new_data=copy_data.drop(columns='Random')

# %%
new_data
# Out:
#    Id  Country   Age   Salary Purchased
# 0   0   France  44.0  72000.0        No
# 1   1    Spain  27.0  48000.0       Yes
# 2   2  Germany  30.0  54000.0        No
# 3   3    Spain  38.0  61000.0        No
# 4   4  Germany  40.0      NaN       Yes
# 5   5   France  35.0  58000.0       Yes
# 6   6    Spain   NaN  52000.0        No
# 7   7   France  48.0  79000.0       Yes
# 8   8  Germany  50.0  83000.0        No
# 9   9   France  37.0  67000.0       Yes

# %%
new_data=new_data.set_index('Id')

# %%
new_data.isnull()
# Out:
#     Country    Age  Salary  Purchased
# Id
# 0     False  False   False      False
# 1     False  False   False      False
# 2     False  False   False      False
# 3     False  False   False      False
# 5     False  False   False      False
# 7     False  False   False      False
# 8     False  False   False      False
# 9     False  False   False      False

# %%
new_data.isnull().sum().shape
# Out:
# (4,)

# %%
new_data.shape
# Out:
# (10, 4)

# %%
new_data.dropna(inplace=True)

# %%
new_data.shape
# Out:
# (8, 4)

# %%
new_data
# Out:
#     Country   Age   Salary Purchased
# Id
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 5    France  35.0  58000.0       Yes
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes

# %%
copy_data.shape
# Out:
# (10, 6)

# %%
copy_data.isnull().sum().shape
# Out:
# (6,)

# %%
new_data.isnull().sum().shape
# Out:
# (4,)

# %%
new_data
# Out:
#     Country   Age   Salary Purchased
# Id
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 5    France  35.0  58000.0       Yes
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes

# %%
new_data.isnull()
# Out:
#     Country    Age  Salary  Purchased
# Id
# 0     False  False   False      False
# 1     False  False   False      False
# 2     False  False   False      False
# 3     False  False   False      False
# 5     False  False   False      False
# 7     False  False   False      False
# 8     False  False   False      False
# 9     False  False   False      False

# %%
copy_data
# Out:
#    Random  Id  Country   Age   Salary Purchased
# 0     NaN   0   France  44.0  72000.0        No
# 1     NaN   1    Spain  27.0  48000.0       Yes
# 2     NaN   2  Germany  30.0  54000.0        No
# 3     NaN   3    Spain  38.0  61000.0        No
# 4     NaN   4  Germany  40.0      NaN       Yes
# 5     NaN   5   France  35.0  58000.0       Yes
# 6     NaN   6    Spain   NaN  52000.0        No
# 7     NaN   7   France  48.0  79000.0       Yes
# 8     NaN   8  Germany  50.0  83000.0        No
# 9     NaN   9   France  37.0  67000.0       Yes

# %%
copy3=copy_data.drop(columns='Random')

# %%
copy2
# Out:
#    Id  Country   Age   Salary Purchased
# 0   0   France  44.0  72000.0        No
# 1   1    Spain  27.0  48000.0       Yes
# 2   2  Germany  30.0  54000.0        No
# 3   3    Spain  38.0  61000.0        No
# 4   4  Germany  40.0      NaN       Yes
# 5   5   France  35.0  58000.0       Yes
# 6   6    Spain   NaN  52000.0        No
# 7   7   France  48.0  79000.0       Yes
# 8   8  Germany  50.0  83000.0        No
# 9   9   France  37.0  67000.0       Yes

# %%
copy2=copy2.set_index('Id')

# %%
copy2
# Out:
#     Country   Age   Salary Purchased
# Id
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Germany  40.0      NaN       Yes
# 5    France  35.0  58000.0       Yes
# 6     Spain   NaN  52000.0        No
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes

# %%
copy2=copy2['Salary'].replace(np.NaN,copy2['Salary'].mean())

# %%
copy2
# Out:
# Id
# 0    72000.000000
# 1    48000.000000
# 2    54000.000000
# 3    61000.000000
# 4    63777.777778
# 5    58000.000000
# 6    52000.000000
# 7    79000.000000
# 8    83000.000000
# 9    67000.000000
# Name: Salary, dtype: float64

# %%
copy3
# Out:
#    Id  Country   Age   Salary Purchased
# 0   0   France  44.0  72000.0        No
# 1   1    Spain  27.0  48000.0       Yes
# 2   2  Germany  30.0  54000.0        No
# 3   3    Spain  38.0  61000.0        No
# 4   4  Germany  40.0      NaN       Yes
# 5   5   France  35.0  58000.0       Yes
# 6   6    Spain   NaN  52000.0        No
# 7   7   France  48.0  79000.0       Yes
# 8   8  Germany  50.0  83000.0        No
# 9   9   France  37.0  67000.0       Yes

# %%
copy3.set_index('Id')
# Out:
#     Country   Age   Salary Purchased
# Id
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Germany  40.0      NaN       Yes
# 5    France  35.0  58000.0       Yes
# 6     Spain   NaN  52000.0        No
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes

# %%
copy4=copy3

# %%
copy3['Salary']=copy3['Salary'].replace(np.NaN,copy3['Salary'].mean())

# %%
copy3
# Out:
#    Id  Country   Age        Salary Purchased
# 0   0   France  44.0  72000.000000        No
# 1   1    Spain  27.0  48000.000000       Yes
# 2   2  Germany  30.0  54000.000000        No
# 3   3    Spain  38.0  61000.000000        No
# 4   4  Germany  40.0  63777.777778       Yes
# 5   5   France  35.0  58000.000000       Yes
# 6   6    Spain   NaN  52000.000000        No
# 7   7   France  48.0  79000.000000       Yes
# 8   8  Germany  50.0  83000.000000        No
# 9   9   France  37.0  67000.000000       Yes

# %%
copy3['Age']=copy3['Age'].replace(np.NaN,int(copy3['Age'].mean()))

# %%
copy3
# Out:
#    Id  Country        Age        Salary Purchased
# 0   0   France  44.000000  72000.000000        No
# 1   1    Spain  27.000000  48000.000000       Yes
# 2   2  Germany  30.000000  54000.000000        No
# 3   3    Spain  38.000000  61000.000000        No
# 4   4  Germany  40.000000  63777.777778       Yes
# 5   5   France  35.000000  58000.000000       Yes
# 6   6    Spain  38.777778  52000.000000        No
# 7   7   France  48.000000  79000.000000       Yes
# 8   8  Germany  50.000000  83000.000000        No
# 9   9   France  37.000000  67000.000000       Yes

# %%
copy3.Purchased.replace(('Yes','No'),(1,0),inplace=True)

# %%
copy3
# Out:
#    Id  Country        Age        Salary  Purchased
# 0   0   France  44.000000  72000.000000          0
# 1   1    Spain  27.000000  48000.000000          1
# 2   2  Germany  30.000000  54000.000000          0
# 3   3    Spain  38.000000  61000.000000          0
# 4   4  Germany  40.000000  63777.777778          1
# 5   5   France  35.000000  58000.000000          1
# 6   6    Spain  38.777778  52000.000000          0
# 7   7   France  48.000000  79000.000000          1
# 8   8  Germany  50.000000  83000.000000          0
# 9   9   France  37.000000  67000.000000          1

# %%
#sklearn.preprocessing
import sklearn.preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
help(LabelEncoder)
# Out:
# Help on class LabelEncoder in module sklearn.preprocessing.label:
#
# class LabelEncoder(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#  |  Encode labels with value between 0 and n_classes-1.
#  |
#  |  Read more in the :ref:`User Guide <preprocessing_targets>`.
#  |
#  |  Attributes
#  |  ----------
#  |  classes_ : array of shape (n_class,)
#  |      Holds the label for each class.
#  |
#  |  Examples
#  |  --------
#  |  `LabelEncoder` can be used to normalize labels.
#  |
#  |  >>> from sklearn import preprocessing
#  |  >>> le = preprocessing.LabelEncoder()
#  |  >>> le.fit([1, 2, 2, 6])
#  |  LabelEncoder()
#  |  >>> le.classes_
#  |  array([1, 2, 6])
#  |  >>> le.transform([1, 1, 2, 6]) #doctest: +ELLIPSIS
#  |  array([0, 0, 1, 2]...)
#  |  >>> le.inverse_transform([0, 0, 1, 2])
#  |  array([1, 1, 2, 6])
#  |
#  |  It can also be used to transform non-numerical labels (as long as they are
#  |  hashable and comparable) to numerical labels.
#  |
# ...

# %%
X = copy3.iloc[:, :-1].values

# %%
X
# Out:
# array([[0, 'France', 44.0, 72000.0],
#        [1, 'Spain', 27.0, 48000.0],
#        [2, 'Germany', 30.0, 54000.0],
#        [3, 'Spain', 38.0, 61000.0],
#        [4, 'Germany', 40.0, 63777.77777777778],
#        [5, 'France', 35.0, 58000.0],
#        [6, 'Spain', 38.77777777777778, 52000.0],
#        [7, 'France', 48.0, 79000.0],
#        [8, 'Germany', 50.0, 83000.0],
#        [9, 'France', 37.0, 67000.0]], dtype=object)

# %%
X_Column=X[: ,1]

# %%
X_Column
# Out:
# array(['France', 'Spain', 'Germany', 'Spain', 'Germany', 'France',
#        'Spain', 'France', 'Germany', 'France'], dtype=object)

# %%
X[:,1]=label_encoder.fit_transform(X[:,1])

# %%
X_Column
# Out:
# array([0, 2, 1, 2, 1, 0, 2, 0, 1, 0])

# %%
X_Column[1]
# Out:
# 2

# %%
X
# Out:
# array([[0, 0, 44.0, 72000.0],
#        [1, 2, 27.0, 48000.0],
#        [2, 1, 30.0, 54000.0],
#        [3, 2, 38.0, 61000.0],
#        [4, 1, 40.0, 63777.77777777778],
#        [5, 0, 35.0, 58000.0],
#        [6, 2, 38.77777777777778, 52000.0],
#        [7, 0, 48.0, 79000.0],
#        [8, 1, 50.0, 83000.0],
#        [9, 0, 37.0, 67000.0]], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder(categorical_features=[0])

# %%
x = onehotencoder.fit_transform(X)
print(x)
# Out:
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (3, 3)	1.0
#   (4, 4)	1.0
#   (5, 5)	1.0
#   (6, 6)	1.0
#   (7, 7)	1.0
#   (8, 8)	1.0
#   (9, 9)	1.0
#   (0, 11)	44.0
#   (0, 12)	72000.0
#   (1, 10)	2.0
#   (1, 11)	27.0
#   (1, 12)	48000.0
#   (2, 10)	1.0
#   (2, 11)	30.0
#   (2, 12)	54000.0
#   (3, 10)	2.0
#   (3, 11)	38.0
#   (3, 12)	61000.0
#   (4, 10)	1.0
#   (4, 11)	40.0
#   (4, 12)	63777.77777777778
#   (5, 11)	35.0
#   (5, 12)	58000.0
#   (6, 10)	2.0
#   (6, 11)	38.77777777777778
#   (6, 12)	52000.0
#   (7, 11)	48.0
#   (7, 12)	79000.0
#   (8, 10)	1.0
#   (8, 11)	50.0
#   (8, 12)	83000.0
#   (9, 11)	37.0
#   (9, 12)	67000.0
# /Users/zwalaneelam/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# ...

# %%
dummy =pd.get_dummies(copy3['Country'])
dummy
# Out:
#    France  Germany  Spain
# 0       1        0      0
# 1       0        0      1
# 2       0        1      0
# 3       0        0      1
# 4       0        1      0
# 5       1        0      0
# 6       0        0      1
# 7       1        0      0
# 8       0        1      0
# 9       1        0      0

# %%
copy3=pd.concat([copy3,dummy],axis=1)

# %%
copy3
# Out:
#    Id  Country        Age        Salary  Purchased  France  Germany  Spain
# 0   0   France  44.000000  72000.000000          0       1        0      0
# 1   1    Spain  27.000000  48000.000000          1       0        0      1
# 2   2  Germany  30.000000  54000.000000          0       0        1      0
# 3   3    Spain  38.000000  61000.000000          0       0        0      1
# 4   4  Germany  40.000000  63777.777778          1       0        1      0
# 5   5   France  35.000000  58000.000000          1       1        0      0
# 6   6    Spain  38.777778  52000.000000          0       0        0      1
# 7   7   France  48.000000  79000.000000          1       1        0      0
# 8   8  Germany  50.000000  83000.000000          0       0        1      0
# 9   9   France  37.000000  67000.000000          1       1        0      0

# %%
copy3=copy3.drop(columns='Country')

# %%
copy3
# Out:
#    Id        Age        Salary  Purchased  France  Germany  Spain
# 0   0  44.000000  72000.000000          0       1        0      0
# 1   1  27.000000  48000.000000          1       0        0      1
# 2   2  30.000000  54000.000000          0       0        1      0
# 3   3  38.000000  61000.000000          0       0        0      1
# 4   4  40.000000  63777.777778          1       0        1      0
# 5   5  35.000000  58000.000000          1       1        0      0
# 6   6  38.777778  52000.000000          0       0        0      1
# 7   7  48.000000  79000.000000          1       1        0      0
# 8   8  50.000000  83000.000000          0       0        1      0
# 9   9  37.000000  67000.000000          1       1        0      0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2)

# %%
y=copy3.iloc[:,2].values

# %%
y
# Out:
# array([72000.        , 48000.        , 54000.        , 61000.        ,
#        63777.77777778, 58000.        , 52000.        , 79000.        ,
#        83000.        , 67000.        ])

# %%
X_test
# Out:
# array([[7, 0, 48.0, 79000.0],
#        [0, 0, 44.0, 72000.0]], dtype=object)

# %%
y_train
# Out:
# array([52000.        , 48000.        , 83000.        , 61000.        ,
#        63777.77777778, 54000.        , 58000.        , 67000.        ])

# %%
y_test
# Out:
# array([79000., 72000.])

# %%
X
# Out:
# array([[0, 0, 44.0, 72000.0],
#        [1, 2, 27.0, 48000.0],
#        [2, 1, 30.0, 54000.0],
#        [3, 2, 38.0, 61000.0],
#        [4, 1, 40.0, 63777.77777777778],
#        [5, 0, 35.0, 58000.0],
#        [6, 2, 38.77777777777778, 52000.0],
#        [7, 0, 48.0, 79000.0],
#        [8, 1, 50.0, 83000.0],
#        [9, 0, 37.0, 67000.0]], dtype=object)
